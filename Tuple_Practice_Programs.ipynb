# %% [markdown]
# <a href="https://colab.research.google.com/github/Shilpashree-S/PDA---23CSE313/blob/main/Tuple_Practice_Programs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise Set 1: Creation and Access

# %% [markdown]
# 1. Create a tuple named colors containing the strings: 'red', 'green', and 'blue'.
# 2. Create a tuple named single containing only the integer 42. (Remember the required syntax!)
# 3. Access and print the middle item from the colors tuple.
# 4. Access and print the last item from the colors tuple using a negative index.
# 5. Write a simple for loop to print every item in the colors tuple.

# %% [markdown]
# # Exercise Set 2: Packing, Unpacking, and Slicing

# %% [markdown]
# 1. Use tuple packing to assign the values 100, 200, and 300 to a single variable named data.
# 2. Unpack the data tuple into three separate variables named a, b, and c.
# 3. Use multiple assignment to swap the values of variables x=5 and y=10 in a single line.
# 4. Given numbers = (1, 2, 3, 4, 5, 6), use slicing to create a new tuple containing only (4, 5).
# 5. Use slicing to reverse the numbers tuple.

# %% [markdown]
# # Exercise Set 3: Functions and Immutability

# %%
grades = (85, 92, 78, 92, 100, 85, 92)

# %% [markdown]
# 1. Find the total number of grades recorded.
# 2. Find the highest and lowest scores.
# 3. Determine how many students received the score 92.
# 4. Find the position of the first occurrence of the score 78.
# 5. Print a new list of the grades in ascending order.
# 6. Predict the result: What happens if you run: grades[0] = 90?
# 7. Given user = ('Alex', [80, 90]), access the second element of the nested list (90) and change its value to 95.

# %% [markdown]
# # Advanced Tuple Exercises

# %% [markdown]
# Q1. You have a tuple representing a user profile: profile = ("Jane Doe", 35, ("New York", 10001)). Unpack this entire structure into four separate variables: name, age, city, and zip_code.

# %% [markdown]
# Q2. Given t = (1, 2, 3, 4, 5). Use slicing to extract the items (1, 2) and the items (5). Then, use the concatenation operator (+) to create a new tuple t_new containing (1, 2, 99, 5).

# %% [markdown]
# Q3. In the tuple data = ('A', 'B', 'C', 'B', 'D', 'B'), find the second occurrence of 'B'. (Hint: Start your search after the first 'B' is located).
