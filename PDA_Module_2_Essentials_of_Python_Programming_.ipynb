# %% [markdown]
# <a href="https://colab.research.google.com/github/Shilpashree-S/PDA---23CSE313/blob/main/PDA_Module_2_Essentials_of_Python_Programming_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello")
# Out:
# Hello
