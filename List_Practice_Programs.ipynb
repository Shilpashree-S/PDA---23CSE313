# %% [markdown]
# <a href="https://colab.research.google.com/github/Shilpashree-S/PDA---23CSE313/blob/main/List_Practice_Programs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. For each object below, create it in Python and determine its data type and whether it is Mutable or Immutable.
#
#   - data_A = [10, 'A', 3.14]
#   - data_B = (1, 2, 3)
#   - data_C = "Hello"
#   - data_D = {1: 'a', 2: 'b'}

# %% [markdown]
# 2. Create an empty list named inventory using square brackets [].

# %% [markdown]
# 3. Create a mixed data list named profile containing your name (string), age (integer), and a boolean value (e.g., True) indicating if you are a student.

# %% [markdown]
# 4. Use a list comprehension to generate a list named even_cubes that contains the cube (x**3) of every even number from the range of 1 to 15 (inclusive).

# %% [markdown]
# 5. Convert the string pythonic_word = "DATA STRUCTURE" into a list of characters named char_list.

# %% [markdown]
# 6. Convert the tuple coordinates_tuple = (40.71, -74.00) into a list named coordinates_list.

# %% [markdown]
# 7. Start with the list
#
# playlist = ["Song A", "Song B", "Song C"].
#
#   - Use .append() to add "Song D" to the end.
#   - Use .insert() to add "Song X" at index 1.
#   - Use .remove() to remove "Song C".
#   - Use .pop() to remove the last song and store it in a variable called last_song.
#   - Use .extend() to add another list new_tracks = ["Song E", "Song F"] to playlist.

# %% [markdown]
# 8. You have a list of temperatures for a week. You want to create a new list containing only the days where the temperature was below 20.
# Use a list comprehension to filter daily_temps into a new list named cool_days.

# %% [markdown]
# 9. Start with the list
#
# data_points = [5, 1, 8, 5, 3, 9, 2, 5].
#   - Use .count() to find how many times the number 5 appears.
#   - Use .index() to find the index of the first occurrence of 3.
#   - Use .sort() to sort the list in place in ascending order.
#   - Use .reverse() to reverse the sorted list (it should now be in descending order).
#   - Use .copy() to create a shallow copy named data_copy.

# %% [markdown]
# 10. Use the list
#
# days = ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"] and the slicing syntax to achieve the following:
#
#   - Extract the weekend days: ["Sat", "Sun"]
#
#   - Extract the first three days: ["Mon", "Tue", "Wed"]
#
#   - Extract everything except the first day: ["Tue", "Wed", "Thu", "Fri", "Sat", "Sun"]
#
#   - Extract every other day, starting from "Mon" (index 0): ["Mon", "Wed", "Fri", "Sun"]
#
#   - Reverse the entire list: ["Sun", "Sat", "Fri", "Thu", "Wed", "Tue", "Mon"]

# %% [markdown]
# Few More Challenges

# %% [markdown]
# 11. You are given a list of student scores:
# scores = [45, 67, 89, 34, 76, 90, 55, 38]
#
# a. Extract scores above 60 using list comprehension.
#
# b. Slice the list to get the scores of the middle four students.

# %% [markdown]
# 12. You have a list of products:
#
# products = ["pen", "notebook", "eraser", "marker", "stapler"]
#
# - Insert "highlighter" between "notebook" and "eraser".
# - Remove "marker" and print the updated list.

# %% [markdown]
# 13. You have a list of existing usernames:
#
# usernames = ["alice", "bob", "charlie", "dave"]
#
#
# Write a function that:
#
#   - Checks if a new username already exists.
#   - If not, adds it to the list and returns the updated list.

# %% [markdown]
# 14. You are given a list of student marks:
#
# marks = [88, 76, 92, 85, 69, 95, 73, 84, 91, 77]
#
#   - Slice the top 5 scorers and calculate their average.
#   - Identify students who scored below the class average.
#   - Sort the list in descending order and display the top 3 performers.

# %% [markdown]
# 15. temperatures = [22.5, 24.0, 19.8, 21.0, 25.2, 23.5, 20.1, 26.3, 27.0, 22.8, 24.5, 23.0, 21.9, 20.5]
#
#   - Slice the temperatures for the second week (days 8–14).
#   - Find the hottest and coldest day in week 2.
#   - Create a new list with only temperatures above 24°C using list comprehension.
