# %% [markdown]
# <a href="https://colab.research.google.com/github/Shilpashree-S/PDA---23CSE313/blob/main/Module_two_Part_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Control Flow Statements in Python
# Control flow structures in Python are essential for directing the execution of a program based on certain conditions and loops. These structures allow for decision-making and repetition, enabling more complex and functional programs. Here’s an overview of the primary control flow structures in Python:
#   ## 1. Decision - Making Structures
# Decision - making structures require the programmer to specify one or more conditions to be evaluated or tested by the program, along with a statement or statements to be executed if the condition is determined to be true, and optionally, other statements to be executed if the condition is detetmined to be false.
#
# - The "if" structure is the general form of a typical decision-making structure found in most of the programming languages.
# -There are 4 types of "if" statements that we can use in Python programming based on the requirement:
# 1.1 "if" Statement
#   - A simple "if" statement consists of a Boolean expression followed by one or more statements.
#   - If the Boolean expression evaluates to be true, then the block of code inside the "if" statement will be executed.
#   - If the condition is false, then the statements inside the "if" statement body are completely ignored
#
# ```python
#   if (boolean_expression):
#     statement (s) will execute if the boolean expression is true
# ```
# ```python
# ![flowchart of if statement](/content/flowchart_of_if_stmt.png)
# ```

# %%
from IPython.display import Image, display
display(Image(filename='/content/flowchart_of_if_stmt.png'))

# %%
#Program to compare share price of two organizations - using if statement.
p1, p2 = eval(input("Input the share price of two organizations: "))

#using if statement.
if p1>p2:
  print("The first organization is performing better")
# Out:
# Input the share price of two organizations: 570,250
# The first organization is performing better

# %% [markdown]
# 1.2 if...else Statement
# - A "if" statement can be followed by an optional "else" statement which is executed when the Boolean expression is false.
# - If the Boolean expression evaluates to be false, then the first set of code after the end of the "else" statement will be executed.
#
# Syntax
# ```python
# if (boolean_expression:
#   statement (s) will execute if the boolean expression is true.
# else:
#   statement (s) will execute if the boolean expression is false.
# ```

# %%
from IPython.display import Image, display
display(Image(filename='/content/flowchart_of_if_else_stmt.png'))

# %%
#Program to compare share prices of two organizations - using if...else.
p1,p2 = eval(input("Input the share price of two organizations: "))
#Using if statement.
if p1>p2:
  print("The first organization is performing better")
else:
  print("The second organization is performing better")
# Out:
# Input the share price of two organizations: 250,570
# The second organization is performinf better

# %% [markdown]
# **Note: It is important to use colon a the end of "if" and "else" statement, otherwise an error will be generated.**

# %% [markdown]
# - It is possible to execute multiple lines if the specified criterion is met. Unlike other programming languages, where we use curly braces to create a block of statement, in Python we define the block through proper indentation.

# %%
#Program to print the result depending on profit.
sales = float(input("Input the sales amount"))
expenses = float(input("Input the expenses"))
profit = sales - expenses
if profit>9000:
  print("Good profit")
  print("Congratulations")
else:
  print("Poor Profit")
  print("Work Hard")
# Out:
# Input the sales amount25000
# Input the expenses10000
# Good profit
# Congratulations

# %% [markdown]
# 1.3 Nested "if" Statement
# - Nested "if" statement means "if" statement inside another "if" statement.
# - Python allows us to nest "if" statements within "if" statements.
# - A nested "if" s "if" statement that is the target of another "if" statement.

# %% [markdown]
# Syntax
# ```python
# if (condition1):
#   Executes when condition1 is true
#   if (condition2):
#     Executes when condition 1 and condition 2 both are true
#   else:
#     Executes when condition 2 is not true but condition 1 is true
# else:
#   Executes when condition 1 is not true
# ```

# %%
from IPython.display import Image, display
display(Image(filename='/content/flowchart_of_nested_if.jpeg'))

# %%
#Program to compute expensive product among three products.
p1,p2,p3 = eval(input("Input the prices of three products: "))
if p1>p2:
  if p1>p3:
    print("First product is expensive")
  else:
    print("Third product is expensive")
else:
  if p2>p3:
    print("Second product is expensive")
  else:
    print("Third product is expensive")
# Out:
# Input the prices of three products: 500,400,300
# First product is expensive

# %% [markdown]
# 1.4 if-elif-else Ladder
# - An "if" statement can be followed by an optional "else if...else" statement, which is very useful to test various conditions using single "if...else if" statement. Here, a user can decide among multiple options.
# - The "if" statements are executed from the top-down.
# - As soon as one of the conditions controlling the "if" is true, the statement associated with that "if" is executed, and the rest of the ladder is bypassed.
# - If none of the conditions are true, then the final "else" statement will be executed
# - When using "if, else if, else" statements, there are few points to keep in mind.
#   - An "if" can have zero or one "else" and it must come after any "else if's".
#   - An "if" can have zero to many "else if's" and they must come before the "else".
#   - Once an "else if" succeeds, none of the remaining else if's or "else's" will be tested.

# %% [markdown]
# Syntax
# ```python
# if boolean_expression 1:
#   Executes when the boolean expression 1 is true.
# elif boolean_expression 2:
#   Executes when the boolean expression 2 is true.
# ............
# else:
#   Executes when none of the above condition is true.

# %%
from IPython.display import Image, display
display(Image(filename='/content/flowchart_of_if_elif_else.jpeg'))

# %%
#Program to print performance depending on quality sold.
qty = eval(input("Input the quantity sold:"))
if qty >= 900:
  print("Excellence Peformance")
elif qty>= 750:
  print("Above Average Performance")
elif qty >= 500:
  print("Average Performance")
else:
  print("Poor Performance")
# Out:
# Input the quantity sold:200
# Poor Performance

# %%
#Program to determine whether the given point lies on the line or not.

#Input the coordinates of line.
a,b,c=eval(input("Enter the coefficients of x,y, and intercept: "))

#Input the coordinates of point.
x,y=eval(input("Enter the coordinates of the point: "))

#Check the condition.
if ((x*a)+(y*b)-c)<0:
  print("The point is on the left side of the line")
elif ((x*a)+(y*b)-c)>0:
  print("The point is on the right side of the line")
else:
  print("The point is on the line")
# Out:
# Enter the coefficients of x,y, and intercept: 5,10,15
# Enter the coordinates of the point: 1,1
# The point is on the line

# %% [markdown]
# - The condition specified in the "if" statement may be a complex expression where the logical operators "and" and "or" can be used.
# - The "and" operator is used when we want both the conditions to be fulfilled simultaneously, whereas the "or" operator is used if we want at least one condition to be fulfilled.

# %%
#Program using Logical operators: or (|), and (&)
salary = eval(input("Input the salary:"))

#Using or (|) operator.
if salary <= 0 | salary >= 300000:
  print("Invalid Salary")

#Using and (&) operator.
if salary < 50000 & salary > 0:
  print("Junior Manager")
if salary > 50000 & salary < 100000:
  print("Middle-Level Manager")
if salary > 100000 & salary < 300000:
  print("Senior manager")
# Out:
# Input the salary:50000
# Senior manager

# %%
#Program to determine whether the string is pangram, consgram or vowgram.
choice = input("Enter your choice: Pangram, Consogram, Vowgram:")

#Defining letters for checking in different scenario.
if choice == "Pangram":
  letters = 'abcdefghijklmnopqrstuvwxyhz'
elif choice =="Consogram":
  letters = 'bcdfghjklmnpqrstvwxyz'
elif choice == "Vowgram":
  letters = 'aeiou'
else:
  print("Not a valid choice")

#Input the string.
user_string = input("Enter the string:")
flag = True

#Check the occurence of each and every letter in the user defined string.
for letter in letters:
  if letter not in user_string.lower():
    flag=False
    break

#Displaying the output.
if flag == False:
  print("Not a ",choice)
else:
  print("It is a ",choice)
# Out:
# Enter your choice: Pangram, Consogram, Vowgram:Vowgram
# Enter the string:Nice Aeronaut
# It is a  Vowgram

# %% [markdown]
# ##**Loops**
# - <div style="text-align: right"><p style = "font-size:45px">A loop statement allows us to execute a statement or group of statements multiple times.</p></div>
# - <div style="text-align: right"><p style = "font-size:45px">Repetitive commands are executed by loops: for loop, while loop, and repeat loop. </p></div>
#
# - <div style="text-align: right"><p style = "font-size:45px"> Python loops are particularly flexible and they are not limited to integers. We can also use loops for character vectors, logical vectors, lists, or expressions. </p></div>

# %% [markdown]
# ###**For Loop**
# - <div style="text-align: justify"><p style = "font-size:45px"> If the number of repetitions are known in advance, then a “for” loop can be used. </p></div>
# - <div style="text-align: justify;"><p style = "font-size:45px"> For executing for loop, we need to specify start, end, and step argument.</p></div>
# - <div style="text-align: justify;"><p style = "font-size:45px"> The command inside the for loop is executed from the counter having specified value as start; every time it is incremented by the value which is specified in step; the new value of the counter is checked till it reaches the value specified in the end argument.</p></div>

# %% [markdown]
# Syntax
# ```python
# for var in range(start, end, step):
#   commands to be executed
# ```

# %% [markdown]
# where
# - var is the variable name
# - start denotes the starting number
# - end denotes the ending number
# - step is the optional step for increment or decrement (default are +1 and −1)

# %%
from IPython.display import Image, display
display(Image(filename='/content/flowchart_of_for_loop.png'))

# %%
#Program for printing the table of a number.
num = int(input("Input the number to print the table:"))
for k in range(1,11):
  print(num,"x",k,"=",num*k)

#Outside the for loop.
print("Finished Task")
# Out:
# Input the number to print the table:6
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60
# Finished Tesk

# %%
#Program for printing the table of a number using step argument.
num = int(input("Input the number to print the table:"))
for k in range(1,11,2):
  print(num,"x",k,"=",num*k)

#Outside the for loop.
print("Finished Task")
# Out:
# Input the number to print the table:6
# 6 x 1 = 6
# 6 x 3 = 18
# 6 x 5 = 30
# 6 x 7 = 42
# 6 x 9 = 54
# Finished Task

# %% [markdown]
# Note:
# - **It is also possible to have negative value for decrementing the value of step.**
#
# For example, if we need to print the table in decreasing order, we should have syntax as:
# ```python
# for k in range(10, 0, −2)
# ```
# In this case, the loop will start from 10 and continue till 1 decrementing the value by 2 each time.
#
# - It is also possible to accept the number from the user for defining the starting and ending arguments.

# %%
#Program to print sum of the series 1 + 2 + 3 + 4 ...
sum = 0
num = int(input("Input the last number of series: "))
for k in range (1,num+1):
  sum = sum+k

#Outside the for loop.
print("The total is:",sum)
print("Finished Task")
# Out:
# Input the last number of series: 5
# The total is: 15
# Finished Task

# %% [markdown]
# Find the difference between the sum of squares up to that number and the number itself.

# %%
#Program to calculate difference between sum of squares and the number.
number = int(input("Enter the number: "))
sum = 0
for i in range(1, number+1):
  sum = sum + (i*i)

#Outside the for loop.
ans = sum - number
print("The answer is",ans)
# Out:
# Enter the number: 3
# The answer is 11

# %% [markdown]
# If a number is 3, then the output will be 11
# i.e.,
#
# 1 *1 + 2 *2 + 3 *3 − 3 = 11.

# %% [markdown]
# We can also have different starting value.

# %%
#Program to generate Fibonacci series.
num = int(input("Numbers of Fibonacci series to be printed: "))
a = 0
b = 1
print(a)
print(b)

#Executing for loop.
for k in range(3, num +1):
  c = a + b
  a = b
  b = c
  print(c)

#Outside the for loop.
print("Finished Task")
# Out:
# Numbers of Fibonacci series to be printed: 5
# 0
# 1
# 1
# 2
# 3
# Finished Task

# %% [markdown]
# Another example of for loop

# %%
#Program for calculating factorial of a number.
num = int(input("Input the number: "))
fact = 1
for k in range (1, num+1):
  fact = fact*k

#Outside the for loop.
print("The answer is:",fact)
print("Finished Task")
# Out:
# Input the number: 5
# The answer is: 120
# Finished Task

# %%
#Program to show use of "For" and "If" in the same program.
num = int(input("Input the number of Items:"))
amount = 0
discount = 0

#Using for loop.
for k in range(1, num+1):
  price = eval(input("Input the price:"))
  quantity = eval(input("input the quantity:"))
  amount = amount + (price*quantity)
print("Total is: ",amount)

#Using "if" conditiona statement.
if amount > 5000:
  discount = amount + 0.1
  print("Discount of 10% = ", discount)
elif amount>3000:
  discount = amount * 0.07
  print("Discount of 7% = ",discount)
elif amount > 1000:
  discount = amount * .05
  print("Discount of 5% = ", discount)
else:
  print("No discount received")

#In main program.
print("Net amount is: ", amount-discount)
print("Finished Task")
# Out:
# Input the number of Items:3
# Input the price:3000
# input the quantity:2
# Input the price:200
# input the quantity:400
# Input the price:400
# input the quantity:4
# Total is:  87600
# Discount of 10% =  87600.1

# %% [markdown]
# ##**Nesting of for Loops**
# - A loop contained within another loop is called a nested loop.
# - These are used when an iterative process is required. These are generally used in multi-dimensional or hierarchical data statements, including matrices, lists, etc.
# - It is important to understand that we can nest “for” loops to a great level, although nesting beyond 4 to 5 levels often makes it difficult to read and understand the code.

# %%
#Program to print the number of stars.
num = int(input("Input the number of lines: "))
for k in range (1,num+1):
  for j in range (1, k+1):
    print("*",end = " ")
  print("\n")
#Outside the for loop.
print("Finished Task")
# Out:
# Input the number of lines: 3
# *
#
# * *
#
# * * *
#
# Finished Task

# %% [markdown]
# **Programming Challenge:**
#
# Create the program as in the previous program using the nested “while” loops and create appropriate conditions for correct results.

# %% [markdown]
# ##**While Loop**
# - The “while” loop executes the same code again and again until a stop condition is met.
# - A condition is tested in starting of “while” loop. If it is true, then loop body is executed.
# - Once the loop body is executed, the condition is tested again, and so forth, until the condition is false, after
# which the loop exits. This means that when the number of loops is not known in advance, we use a “while” loop.
# - A situation that might occur in a “while” loop is that the loop might not run ever. When the condition is tested and the result is false, the loop body will be skipped and the first statement after the while loop will be executed. - Besides, the programmer needs to be careful that the counting variable within the loop is incremented, otherwise an infinite loop occurs.

# %% [markdown]
# Syntax
# ```python
# while (condition):
#   commands to be executed as long as condition is TRUE
# ```

# %%
from IPython.display import Image, display
display(Image(filename='/content/flowchart_of_while_loop.png'))

# %%
#Program using while loop to print numbers within a range.
counter = 101
while counter <= 105:
  print(counter)
  counter += 1
#Outside the while loop.
print("Finished Task")
# Out:
# 101
# 102
# 103
# 104
# 105
# Finished Task

# %%
#Incorrect program using while (in absence of counter incremenet).
counter = 101
while counter <= 105:
  print(counter)

#Outside the while loop.
print("Finished Task")
# Out:
# Streaming output truncated to the last 5000 lines.
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# ...

# %% [markdown]
# **Definite Loops**
#
# - Used when the number of iterations is known in advance.
# - Typically implemented using the "for" loop.
# - Example: Looping through a list of fixed length.
#
# **Indefinite Loops**
#
# - Required when the number of iterations is unknown.
# - Useful in real-world scenarios where the loop execution count can't be predicted.
# - Best implemented using the "while" loop.

# %%
#Program to show use of while loop for computing bill amount.
amount = 0
choice = "yes"

#Using while loop.
while choice == "yes":
  price = eval(input("Input the price:"))
  quantity = eval(input("Input the quantity:"))
  amount = (price*quantity)+amount
  choice = input("Wish to Continue - yes/no: ")

#Outside the loop.
print("Your bill amount is: ", amount)
print("Finished Task")

# %%
#Program to find the sum of digits of a number.
num = int(input("Enter the number: "))
sum = 0
#Using while loop.
while num>0:
  rem = num % 10
  sum = sum +rem
  num = num // 10
#Outside the loop.
print("The sum of the numbers is: ", sum)

# %% [markdown]
# ##**Nesting of “While” Loops**
# Like “for” loops, it is also possible to nest “while” loops as shown in the following example:

# %%
#Program using nested while loops.
k = 1
x = int(input("Input the number of lines: "))
#Using nested while loops.
while k <= x:
  j = 1
  while j <= k:
    print(j,end=" ")
    j = j+1
  print("\n")
  k = k + 1
#Outside the loop.
print("Finished Task")
# Out:
# Input the number of lines: 3
# 1
#
# 1 2
#
# 1 2 3
#
# Finished Task

# %% [markdown]
# ##**Nesting of Conditional Statements and Loops**
# It is also possible to nest conditional statement and different loops. For example, conditional statement can be inside for/while loop or for/while loop can be inside conditional statement.

# %% [markdown]
# ###**The “for” Loop inside “if” Conditional Statement**
# The following program shows the usage of for loop inside “if” conditional statement.

# %%
#Program for printing even/odd numbers depending on user's choice.
choice = int(input("Enter your choice: 1 for odd, 2 for even: "))
#Using for inside if structure.
if choice==1:
  print("Odd numbers in the range are:")
  for k in range(11,21,2):
    print(k)
elif choice==2:
    print("Even numbers in the range are:")
    for k in range(2,11,2):
      print(k)
else:
    print("Invalid choice")
#Outside the loop and decision structure.
print("Finished Task")
# Out:
# Enter your choice: 1 for odd, 2 for even: 3
# Invalid choice
# Finished Task

# %% [markdown]
# ###**The “if” Conditional Statement Inside “for” Loop**
# The following program considers “if” statement inside “for” loop.

# %%
#Program to compute the length of a given string ignoring spaces.
string = input("Enter the String: ")
count = 0
#Use of if inside for loop.
for letter in string:
  if letter != ' ':
    count = count + 1
#Outside the loop.
print("The length of the string is: ", count)
print("Finished Task")
# Out:
# Enter the String: Python
# The length of the string is:  6
# Finished Task

# %%
#Program to print all different arrangements of the letters M, N, and O.
for first in 'MNO':
  for second in 'MNO':
    if second != first:
      for third in 'MNO':
        if third != first and third != second:
          print(first + second +third)
#Outside the for loop.
print("Finished Task")
# Out:
# MNO
# MON
# NMO
# NOM
# OMN
# ONM
# Finished Task

# %% [markdown]
# ###Kangaroo Words: String Comparison
# A Kangaroo Word is a word that carries another word within it, without rearranging letters.
#
# Example:
#
# Encourage contains:
# courage, cog, cur, urge, core, cure, nag, rag, age, nor, rage, enrage.
#
# But not: run, gen, gone.
#
# Process for Determining a Kangaroo Word:
#
# **Check Each Letter:**
# - For each letter in the second word, find it in the first word.
#
# **Index Comparison:**
# - Check if letters occur in order, starting from where the previous letter was found.
#
# **Mismatch Conditions:**
# - If a letter is missing or out of order, set a flag to false.
# If the length of the first word is shorter than the second, there's an automatic mismatch.

# %%
#Program to determine whether one string is kangaroo word of second.
string1 = input("Enter the first string: ")
string2 = input("Enter the second string: ")
flag = True

#Check the basic condition.
if len(string1) < len(string2):
  print("Wrong!!! Second string is bigger than the first string")
#Execute if the basic condition is satisfied.
else:
  val =0
  for i in range (0,len(string2)):
    for j in range (val,len(string1)):
      if (string2[i] == string1[j]):
        val = j
        flag = True
        break
      else:
        flag = False
    if flag == False:
      break
#Displaying the output
if flag == False:
  print("It is not a kangaroo word")
else:
  print("It is a kangaroo word")
# Out:
# Enter the first string: Python
# Enter the second string: ty
# It is not a kangaroo word

# %% [markdown]
# ###**The “if” Conditional Statement Inside “while” Loop**
# The following program considers “if” statement inside “while” loop.

# %%
#Program to perform the operation randomly depending on user's choice.
Total = 0
choice = "yes"
#Use of if statement inside the while loop.
while choice == "yes":
  operation = input("Choice: A(Add) or S(Sub):")
  amount = int(input("Enter the number: "))
  if operation == 'A':
    Total += amount
  elif operation == "S":
    Total -= amount
  else:
    pass
  choice = input("Wish to Continue - yes/no: ")
#Outside the loop.
print("The total is: ",Total)
print("Finished Task")
# Out:
# Choice: A(Add) or S(Sub):A
# Enter the number: 10
# Wish to Continue - yes/no: yes
# Choice: A(Add) or S(Sub):S
# Enter the number: 4
# Wish to Continue - yes/no: yes
# Choice: A(Add) or S(Sub):A
# Enter the number: 10
# Wish to Continue - yes/no: no
# The total is:  16
# Finished Task

# %% [markdown]
# ###**Using “for”, “while”, and “if” Together**
# The following program uses all “for”, “while”, and “if” in the same program.

# %%
#Program to use three control flow statements in a single program.
choice = eval(input("Enter your choice: 1 or 2: "))
if choice == 1:
  start = eval(input("Input the starting number of range:"))
  end = eval(input("Input the ending number of range: "))
  for x in range(start, end):
    print(x, end = ' ')
elif choice == 2:
  ans = "y"
  value = 111
  while ans == "y":
    print(value)
    value=value + 1
    ans = input("Press y to continue: ")
else:
  print("Invalid choice")
#Outside the loop and decision making statements.
print("Finished Task")
# Out:
# Enter your choice: 1 or 2: 2
# 111
# Press y to continue: y
# 112
# Press y to continue: y
# 113
# Press y to continue: n
# Finished Task

# %% [markdown]
# ###**Abnormal Loop Termination**
# - Loops execute until their condition becomes false.
# - Condition is checked at the beginning of each iteration.
# - If the condition becomes false mid-loop, the loop doesn’t exit immediately.
# - Normally, loops execute all statements within the body.
# - In rare scenarios, loops need to exit prematurely.
# - Solution: Use control statements like break, pass, and continue.
#
# **Loop Control Statements**
# - break: Exits the loop immediately.
# - continue: Skips the current iteration and moves to the next.
# - pass: Does nothing, acts as a placeholder.
#
# **Impact of Abnormal Termination**
#
# - Objects created within the loop’s scope are destroyed upon loop exit.
# - Abnormal termination introduces exceptions to the normal control flow.
#
# **Best Practices for Loops**
# - Every loop should have a normal flow with a single entry and exit point.
# - Avoid abnormal terminations when possible to maintain clean control flow.

# %% [markdown]
# ###**Break Statement**
# - The break statement terminates the loop.
# - Execution transfers to the statement immediately after the loop.
# - When encountered, the loop ends immediately, regardless of the current iteration.
# - The rest of the loop body is skipped.
# - It doesn’t check the loop's condition; it directly exits the loop.
# - Execution resumes with the statement following the loop.
# - break only exits the loop in which it’s placed.
# - Nested loops: break affects only the current loop, not outer loops.

# %%
#Program to show use of break statement to terminate for loop in between.
for num in range(11, 20):
  print(num)
  if num > 15:
    break
#Outside the loop and decision making statement.
print("Finished Task")
# Out:
# 11
# 12
# 13
# 14
# 15
# 16
# Finished Task

# %% [markdown]
# The break statement can also be used inside a "while" loop, as demonstrated in the following program:

# %%
#Program to use break statement to terminate while loop in between.
total = 0
print("Enter positive integer numbers to add; negative number to end.")
while True:
  amount = eval(input("Input the amount:"))
  if amount < 0:
    break
  total += amount
#Outside the loop and decision making statement.
print("The total is = ",total)
print("Finished Task")
# Out:
# Enter positive integer numbers to add; negative number to end.
# Input the amount:40
# Input the amount:30
# Input the amount:30
# Input the amount:-9
# The total is =  100
# Finished Task

# %% [markdown]
# Note: In a nested loop, the break statement exits only the loop in which the break is found.

# %%
#Program to display prime numbers till a number.
limit = eval(input("Enter largest limit for displaying prime numbers: "))
for value in range(2, limit+1):
  is_prime = True
  for factor in range(2, value):
    if value % factor ==0:
      is_prime = False
      break
  if is_prime:
      print(value,end=' ')
#Outside the loop and decision making statement.
print()
print("Finished Task")
# Out:
# Enter largest limit for displaying prime numbers: 10
# 2 3 5 7
# Finished Task

# %%
#Program to print prime numbers from 5 till the user-specified number.
k = 1
limit = int(input("Enter largest limit for printing prime numbers:"))
while k < limit:
  j = 2
  while j <= (k/j):
    if not (k%j):
      break
    j = j + 1
    if j > k/j:
      print (k, end = ' ')
  k = k + 1
#Outside the loop and decision making statement.
print()
print("Finished Task")
# Out:
# Enter largest limit for printing prime numbers:10
# 5 7
# Finished Task

# %% [markdown]
# ###**Continue Statement**
# When a continue statement is encountered:
# - The current iteration of the loop is skipped.
# - The loop’s condition is checked again for the next iteration.
# - If the condition is true, the loop starts from the top.
#
# break and continue in Nested Loops
# - Both break and continue only affect the loop in which they are placed.
# - In nested loops, they will only control the inner loop, not the outer loop.

# %%
#Program to add positive integers till user enters 0.
total = 0
complete = False
while not complete:
  amount = eval(input("Input the number (press 0 to quit):"))
  if amount < 0:
    print("Wrong!!!, You entered a negative value",amount)
    continue
  #Skip rest of body for this iteration.
  if amount == 0:
    complete = True
  else:
    total += amount
#Outside the loop and decision making statement.
print("The total number is = ", total)
print("Finished Task")
# Out:
# Input the number (press 0 to quit):3
# Input the number (press 0 to quit):3
# Input the number (press 0 to quit):-1
# Wrong!!!, You entered a negative value -1
# Input the number (press 0 to quit):3
# Input the number (press 0 to quit):3
# Input the number (press 0 to quit):0
# The total number is =  12
# Finished Task

# %% [markdown]
# ###**Pass Statement**
# In programming, pass is a placeholder statement. It's used when you create a code block but don't need to run any code in it. When pass is executed, nothing happens.

# %%
#Using pass statement.
for letter in 'HELLO':
  pass
print("The last letter is :", letter)
print("Finished Task")
# Out:
# The last letter is : O
# Finished Task

# %% [markdown]
# ##**User-Defined Functions**
# - The function is a standard unit of reuse.
# - Functions are essential for large or complex programs.
# - They help organize tasks sequentially using a top-down modular approach.
# - Simplify debugging due to modularity.
# - Reduce code complexity by breaking tasks into smaller, manageable parts.
# - The interpreter passes control to the function with arguments.
# - The function performs its task and returns control and any result to the interpreter.
# - Python allows creating custom functions to extend its functionality.
# - These functions act like built-in functions and can be reused or shared.
# - A function consists of:
#   - Name: Identifies the function.
#   - Parameters: Values passed to the function (may be empty).
#   - Result: The output produced (could be None).
# - Functions can have parameters or no arguments.
# - They allow developers to define an interface for users to interact with the code.

# %% [markdown]
# Syntax:
# ```python
# def fname(arg1, arg2, ...):
#   function body
# ```
# where,
# - fname is the actual name of the function stored in Python environment.
# - arg1, arg2 are the optional arguments. An argument is like a placeholder. When a function is invoked, we pass a value to the argument. This value is referred to as actual parameter or argument. The argument list refers to the order and number of the arguments of a function. A function can/cannot contain arguments.
# - function body contains a collection of statements that define the task of function.
# - The function name along with the list of arguments together form the function's signature.
#
# - A function's task is defined upon creation.
# - To execute the task, the function must be called.
# - Calling a function transfers control to the function.
# - The function performs its designated task.
# - Control is returned to the main program when the return statement is executed or the last line is reached.
# - To call a function, provide the required parameters along with the function name.
# - If the function returns a value, store it in a variable.

# %% [markdown]
# ###**Function without Arguments**
# - A function without arguments can be created using an empty parentheses, because all arguments inside a function are passed within parentheses.
# - It should be noted that a function without arguments can be created with or without return statement.

# %%
#Create a function without arguments and without return statement.
def hello():
  print("Welcome to world of Python")
  print("Good Day")
#Calling the function.
hello()
# Out:
# Welcome to world of Python
# Good Day

# %% [markdown]
# The major advantage of function is that it can be created once and called many times.

# %%
#Calling a function multiple times in the same program.
def hello():
  print("Hello")
  print("Enjoy Learning")
#Calling the function multiple times.
hello()
hello()
hello()
# Out:
# Hello
# Enjoy Learning
# Hello
# Enjoy Learning
# Hello
# Enjoy Learning

# %% [markdown]
# A function body can also contain some expressions and hence function can also produce some results.

# %%
#Creating a function with arguments and compute the result for arguments.
def function():
  num1 = 100
  num2 = 200
  print("The result is: ",num1 + num2)
#Calling the function.
function()
# Out:
# The result is:  300

# %% [markdown]
# A function becomes more maningful and will yield better results if programming is also done using loops and decision - making statements in the function body. This is helpful for doing effective analysis and decision making in Python.

# %%
#Creating a function without an argument and using a "for" loop.
def function2():
  for num in range(1,6):
    print(num * 7)
#Calling the function.
function2()
# Out:
# 7
# 14
# 21
# 28
# 35

# %% [markdown]
# It is also possible to create multiple functions in the single program as demonstrated in the below example:

# %%
# Program for creating multiple functions in a single program.

# Creating area_square function for calculating the area of a square.
def area_square():
    side = eval(input("Input the length of the square: "))
    print("The area of the square is:", side * side)

# Creating area_circle function for calculating the area of a circle.
def area_circle():
    rad = eval(input("Input the radius of the circle: "))
    print("The area of the circle is:", 3.14 * rad * rad)

# Creating area_rectangle function for calculating the area of a rectangle.
def area_rectangle():
    length, breadth = eval(input("Input length and breadth of the rectangle: "))
    print("The area of the rectangle is:", length * breadth)

# Creating area_triangle function for calculating the area of a triangle.
def area_triangle():
    a, b, c = eval(input("Input the three sides of the triangle: "))
    s = (a + b + c) / 2
    area = (s * (s - a) * (s - b) * (s - c)) ** 0.5
    print("The area of the triangle is:", area)

# Calling the function according to user choice.
choice = int(input("Choice: 1-square, 2-circle, 3-rectangle, 4-triangle: "))

if choice == 1:
    area_square()
elif choice == 2:
    area_circle()
elif choice == 3:
    area_rectangle()
elif choice == 4:
    area_triangle()
else:
    print("Not a valid choice")
# Out:
# Choice: 1-square, 2-circle, 3-rectangle, 4-triangle: 1
# Input the length of the square: 2
# The area of the square is: 4

# %% [markdown]
# It should be noted that the variable created inside the function is not known outside the function. Hence, an error will be generated if the variable is called outside the function. This is demonstrated in the following example:

# %%
#Program for understanding the scope of a variable in a function.
#Creating function without returning the output.
def trial_func():
  print_value = 4000
#Calling the variable defined inside the function.
print(print_value)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-9366796c3f26> in <cell line: 6>()
#       4   print_value = 4000
#       5 #Calling the variable defined inside the function.
# ----> 6 print(print_value)
#
# NameError: name 'print_value' is not defined

# %% [markdown]
# - A function can also return some variable which needs to be handled in the main program.
# - We can directly store the returned value from a function to a variable and then print the value of that variable in the main program.
# - The use of return statement will shift the control back to the place from where the function was called.
# - It is important to note that a function can have only one return statement; however, the return statement can return multiple values.

# %%
#Creating a function without arguments and returning a single value.
def bill():
  print("Welcome")
  amount = 4000
  return amount
#Calling a function
value = bill()
print(value)
# Out:
# Welcome
# 4000

# %% [markdown]
# In Python, the function can also return a Boolean value to the main program unlike most of the programming languages. This is demonstrated in the following program:

# %%
#Program to create a function that returns a Boolean value.
def multiple():
  num1, num2 = eval(input("Input the two numbers: "))
  if num1 % num2 == 0:
    return True
  else:
    return False
#Main Program calling the function.
print("The number is a multiple:", multiple())
# Out:
# Input the two numbers: 40,5
# The number is a multiple: True

# %% [markdown]
# The user can also create multiple functions in the same program and each functin can return output separately from its function.

# %%
# Program for using return in multiple functions in a single program.

# Creating area_square function for calculating the area of a square.
def area_square():
    side = eval(input("Input the length of the square: "))
    return side * side

# Creating area_circle function for calculating the area of a circle.
def area_circle():
    rad = eval(input("Input the radius of the circle: "))
    return 3.14 * rad * rad

# Creating area_rectangle function for calculating the area of a rectangle.
def area_rectangle():
    length, breadth = eval(input("Input length and breadth of the rectangle: "))
    return length * breadth

# Creating area_triangle function for calculating the area of a triangle.
def area_triangle():
    a, b, c = eval(input("Input the three sides of the triangle: "))
    s = (a + b + c) / 2
    return (s * (s - a) * (s - b) * (s - c)) ** 0.5

# Main program to call the functions based on user choice.
choice = int(input("Choice: 1-square, 2-circle, 3-rectangle, 4-triangle: "))

if choice == 1:
    area = area_square()
    print("The area of the square is:", area)
elif choice == 2:
    area = area_circle()
    print("The area of the circle is:", area)
elif choice == 3:
    area = area_rectangle()
    print("The area of the rectangle is:", area)
elif choice == 4:
    area = area_triangle()
    print("The area of the triangle is:", area)
else:
    print("Not a valid choice")
# Out:
# Choice: 1-square, 2-circle, 3-rectangle, 4-triangle: 2
# Input the radius of the circle: 5
# The area of the circle is: 78.5

# %% [markdown]
# - Python also supports the return of multiple values as illustrated in the following program.
# - However, it is necessary that the number of values returned from the function should be equal to the number of variables where those values are stored.

# %%
# Creating a function that returns multiple values.
def amount():
    print("Using return for multiple values")

    Maharashtra = 5000
    Gujarat = 2500
    Delhi = 4000

    return Maharashtra, Gujarat, Delhi

# Calling the function and storing returned values.
a1, a2, a3 = amount()

# Printing the sales in different states.
print("Sale in Maharashtra is:", a1, "Gujarat is:", a2, "Delhi is:", a3)
# Out:
# Using return for multiple values
# Sale in Maharashtra is: 5000 Gujarat is: 2500 Delhi is: 4000

# %% [markdown]
# ###**Function with Arguments**
# - It has been observed that when the user-defined function is created without any argument, the user is not able to change the input given to the function since the variables are assigned predefined value inside the function.
# - But, in practical scenario, the user needs to pass the input as an argument to the function, because the input will change with every execution and every
# requirement.
# - It is important to note that number of arguments while creating a function should be equal to number of arguments passed while calling the function. However, we can pass any number of arguments inside the function.

# %% [markdown]
# Create a User-Defined Function with Single Argument

# %%
# Creating a function with a single argument to print the table of a number.
def table(num):
    for i in range(1, 11):
        print(num, "*", i, "=", num * i)

# Example usage:
table(5)  # This will print the multiplication table of 5
# Out:
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
# 5 * 10 = 50

# %% [markdown]
# It is also possible to consider multiple arguments while creating a function as discussed in the following example. This example uses three arguments for creating a table:

# %%
# Creating a function with multiple arguments.
def newtable(num1, num2, num3):
    for i in range(num2, num3 + 1):  # Add 1 to num3 to include it in the range
        print(num1, "*", i, "=", num1 * i)

# Calling the function with three arguments by position of arguments.
print("Printing the table using three arguments")
newtable(7, 1, 3)

# Calling the function with three arguments by names of the arguments.
print("Printing the table using names of the arguments")
newtable(num1=7, num2=3, num3=5)

# Calling the function with three arguments by changing order of arguments.
print("Printing the table by changing the order of three arguments")
newtable(num3=6, num1=7, num2=4)  # You can change the order of arguments if named properly
# Out:
# Printing the table using three arguments
# 7 * 1 = 7
# 7 * 2 = 14
# 7 * 3 = 21
# Printing the table using names of the arguments
# 7 * 3 = 21
# 7 * 4 = 28
# 7 * 5 = 35
# Printing the table by changing the order of three arguments
# 7 * 4 = 28
# 7 * 5 = 35
# 7 * 6 = 42

# %% [markdown]
# It is possible to create multiple functions in the same program having different numbers of arguments. For proper understanding, the same “area” program is considered intentionally with different number of arguments in each function and without return statement.

# %%
# Program to compute area with arguments and without return statement.

# Creating area_square function for calculating the area of a square.
def area_square(side):
    print("The area of the square is:", side * side)

# Creating area_circle function for calculating the area of a circle.
def area_circle(rad):
    print("The area of the circle is:", 3.14 * rad * rad)

# Creating area_rectangle function for calculating the area of a rectangle.
def area_rectangle(length, breadth):
    print("The area of the rectangle is:", length * breadth)

# Creating area_triangle function for calculating the area of a triangle.
def area_triangle(a, b, c):
    s = (a + b + c) / 2
    area = (s * (s - a) * (s - b) * (s - c)) ** 0.5
    print("The area of the triangle is:", area)

# Calling the function according to user choice.
choice = int(input("Choice: 1-square, 2-circle, 3-rectangle, 4-triangle: "))

if choice == 1:
    side = float(input("Input the length of the square: "))
    area_square(side)

elif choice == 2:
    rad = float(input("Input the radius of the circle: "))
    area_circle(rad)

elif choice == 3:
    length, breadth = map(float, input("Input length and breadth of the rectangle (separated by a comma): ").split(','))
    area_rectangle(length, breadth)

elif choice == 4:
    a, b, c = map(float, input("Input the three sides of the triangle (separated by a comma): ").split(','))
    area_triangle(a, b, c)

else:
    print("Not a valid choice")

# %% [markdown]
# We will consider the same “area” program for understanding the difference in programming when the function is created with arguments and also returns the value to the main program.

# %%
# Creating functions with arguments and with return statements.

# Function to calculate the area of a square.
def area_square(side):
    return side * side

# Function to calculate the area of a circle.
def area_circle(rad):
    return 3.14 * rad * rad

# Function to calculate the area of a rectangle.
def area_rectangle(length, breadth):
    return length * breadth

# Function to calculate the area of a triangle using Heron's formula.
def area_triangle(a, b, c):
    s = (a + b + c) / 2
    # Correct Heron's formula: √[s(s - a)(s - b)(s - c)]
    area = (s * (s - a) * (s - b) * (s - c)) ** 0.5
    return area

# Calling the function according to user choice.
choice = int(input("Choice: 1-square, 2-circle, 3-rectangle, 4-triangle: "))

if choice == 1:
    side = float(input("Input the length of the square: "))
    area = area_square(side)

elif choice == 2:
    rad = float(input("Input the radius of the circle: "))
    area = area_circle(rad)

elif choice == 3:
    length, breadth = map(float, input("Input the length and breadth of the rectangle (separated by a comma): ").split(','))
    area = area_rectangle(length, breadth)

elif choice == 4:
    a, b, c = map(float, input("Input the three sides of the triangle (separated by a comma): ").split(','))
    area = area_triangle(a, b, c)

else:
    print("Not a valid choice")
    area = None

if area is not None:
    print("The area of the shape is:", area)

# %% [markdown]
# - The main utility of functions is to create it once and use it for many times. The following example creates a function once and uses it two times to determine whether two numbers ae amicable.
# - Two numbers are said to be amicable if the sum of proper divisors of one number plus 1 is equal to the other number. All divisors of a number other than 1 and itself are called proper divisors.
# - For example, the numbers 220 and 284 are amicable as the sum of proper divisors of 220 (i.e.) 1, 2, 4, 5, 10, 11, 20, 22, 44, 55 and 110 is equal to 284 and sum of proper divisors of 284 (i.e.) 1, 2, 4, 71 and 142 is 220.

# %%
# Function to calculate the sum of factors of a number.
def sum_of_factors(num):
    sum = 1  # Start with 1 because 1 is a factor of every number.
    factors = [1]
    for i in range(2, num):
        if num % i == 0:
            sum += i
            factors.append(i)
    return sum,factors

# Accepting input from the user.
x, y = eval(input("Enter the two numbers separated by a comma: "))

# Calling the function.
val1, factors_x = sum_of_factors(x)
val2, factors_y = sum_of_factors(y)

# Check if the numbers are amicable.
if (val1 == y) and (val2 == x):
    print("The numbers are amicable")
else:
    print("The numbers are not amicable")
print(f"Factors of {x} are {factors_x}")
print(f"Factors of {y} are {factors_y}")
# Out:
# Enter the two numbers separated by a comma: 220,284
# The numbers are amicable
# Factors of 220 are [1, 2, 4, 5, 10, 11, 20, 22, 44, 55, 110]
# Factors of 284 are [1, 2, 4, 71, 142]

# %% [markdown]
# **Fun Fact**
# - The Pythagoreans were the first to identify 220 and 284 as amicable numbers. They studied number properties as part of their philosophy, which included the belief that the world could be explained through mathematics.
# - The amicable relationship between these numbers, where each number's divisors sum to the other, was seen as a perfect mathematical bond, representing harmony and balance in the universe.

# %%
# Function to return the integer value of a Roman numeral character.
def value(roman):
    if roman == 'I':
        return 1
    if roman == 'V':
        return 5
    if roman == 'X':
        return 10
    if roman == 'L':
        return 50
    if roman == 'C':
        return 100
    if roman == 'D':
        return 500
    if roman == 'M':
        return 1000
    return -1  # Return -1 if the character is not a valid Roman numeral.

# Input the Roman numeral from the user.
roman_num = input("Enter the Roman numeral: ").upper()

length = len(roman_num)
ans = 0  # Variable to store the result.

# Loop through the Roman numeral string.
for i in range(length):
    # Get the value of the current Roman numeral character.
    current_value = value(roman_num[i])

    # If there is a next character and its value is greater, subtract the current value.
    if i + 1 < length and value(roman_num[i + 1]) > current_value:
        ans -= current_value
    else:
        ans += current_value

# Display the output.
print("The equivalent integer value of the Roman numeral is:", ans)
# Out:
# Enter the Roman numeral: VI
# The equivalent integer value of the Roman numeral is: 6

# %% [markdown]
# ###**Nesting of Functions**
# - The concept of nesting of function is to define one function within other function.
# - Due to simple recursive scope rules, inside function is itself invisible outside of its immediately enclosing function, but can see (access) all local objects (data, functions, types, etc.) of its immediately enclosing function as well as of any function(s) which, in turn, encloses that function.

# %%
# Program to show nested functions.

# Create two functions.
def greet():
    print("Hello Dear!!!")

def welcome():
    # Calling the nested greet() function inside welcome().
    greet()
    print("Welcome to Python World!!!")

# Calling the single function 'welcome'.
welcome()
# Out:
# Hello Dear!!!
# Welcome to Python World!!!

# %% [markdown]
# We can nest functions theoretically to unlimited depth.

# %%
# Function to print a greeting message
def greet():
    print("Hello Dear!!!")

# Function to print a welcome message and call greet() function
def welcome():
    greet()
    print("Welcome to Python World!!!")

# Function to check if a number is an Armstrong number
def armstrong(num):
    # Step 1: Find the number of digits in 'num'
    num_digits = len(str(num))  # Convert number to string to easily count digits

    # Step 2: Initialize sum to 0
    sum = 0
    n = num  # Copy the original number for manipulation

    # Step 3: Loop through each digit of the number
    while n > 0:
        ans = n % 10  # Extract the last digit
        sum = sum + (ans ** num_digits)  # Raise the digit to the power of num_digits and add to sum
        n = n // 10  # Remove the last digit

    # Step 4: Check if the sum is equal to the original number
    if sum == num:
        print(f"{num} is an Armstrong number.")
    else:
        print(f"{num} is not an Armstrong number.")


# Main task function that calls armstrong() and prints a closing message
def task():
    armstrong(153)
    print("Thanks!!!")

# Calling functions
welcome()
task()
print("See You!!!")
# Out:
# Hello Dear!!!
# Welcome to Python World!!!
# 153 is an Armstrong number.
# Thanks!!!
# See You!!!

# %% [markdown]
# We can also use return statement inside the function along with the calling of any other function as illustrated in the following example:

# %%
# Function to print a welcome message
def welcome():
    print("Welcome to Python World!!!")

# Function to reverse a number, which calls the welcome function
def reverse(num):
    welcome()  # Call the welcome function inside reverse
    reverse_num = 0
    while num > 0:
        remainder = num % 10  # Extract the last digit
        reverse_num = (reverse_num * 10) + remainder  # Build the reversed number
        num = num // 10  # Remove the last digit
    return reverse_num  # Return the reversed number

# Calling the reverse function and storing the result
result = reverse(613)

# Printing the reversed number
print("The reversed number is:", result)
# Out:
# Welcome to Python World!!!
# The reversed number is: 316

# %% [markdown]
# After the execution of return statement, the control transfers to the main program. Hence, it is necessary to check the order of statements inside a function else all the statements in the program will not be executed. This is explained in the following program:

# %%
# Function to print a welcome message
def welcome():
    print("Welcome to Python World!!!")

# Function to reverse a number, which calls the welcome function
def reverse(num):

    reverse_num = 0
    while num > 0:
        remainder = num % 10  # Extract the last digit
        reverse_num = (reverse_num * 10) + remainder  # Build the reversed number
        num = num // 10  # Remove the last digit
    return reverse_num  # Return the reversed number
    welcome()

# Calling the reverse function and storing the result
result = reverse(613)
  # Call the welcome function inside reverse
# Printing the reversed number
print("The reversed number is:", result)
# Out:
# The reversed number is: 316

# %% [markdown]
# It is also possible to pass a string argument in the function and the nesting of functions is also possible for string argument. This is illustrated in the following example:

# %%
# Function to determine whether each letter in a string is a vowel or consonant.
def vowel(input_str):
    vowel_set = ['a', 'e', 'i', 'o', 'u']

    for letter in input_str:
        if letter.isalpha():  # Check if the character is a letter
            if letter.lower() in vowel_set:  # Check in lower case
                print("The letter", letter, "is a vowel")
            else:
                print("The letter", letter, "is a consonant")
        else:
            print("The character", letter, "is not an alphabetic letter.")

# Function to determine the length of the string.
def length(input_str):
    count = 0

    for letter in input_str:
        if letter != '':  # Check if the letter is not an empty string
            count += 1  # Increment the count

    return count  # Return the final count

# Main function for accepting user's choice.
def main():
    choice = int(input("Choice 1 for Determining Vowel, 2 for Length: "))
    user_string = input("Input the string: ")

    if choice == 1:
        vowel(user_string)
    elif choice == 2:
        print("The length of the string is:", length(user_string))
    else:
        print("Invalid choice")

# Main Program Loop
valid = "yes"

while valid.lower() == "yes":
    main()
    valid = input("Do you wish to continue? (yes/no): ")

print("Finished Task")

# %% [markdown]
# ##Recursive Functions
# A recursive function calls itself from its own body of function. In specific situations, it helps in reducing lines of code to a great extent and is highly useful.

# %%
# Creating a recursive function for computing factorial.
def factorial(num):
    if num == 0:  # Check if the number is 0
        return 1  # The factorial of 0 is 1
    else:
        return num * factorial(num - 1)  # Recursive call

# Calling the function
value = int(input("Input the number: "))  # Get user input
print("The factorial of", value, "is:", factorial(value))  # Output the result

# %% [markdown]
# ##Scope of Variables within Functions
# It should be noted that the variables which are defined in the main program can be accessed by
# all the functions defined in the program and hence computation can be done using those
# variables inside the body of the function

# %%
# Global variable
total = 1000

# Creating function
def offer():
    discount = 300  # Local variable
    print("The amount is:", total - discount)  # Using the global variable

# Calling the function
offer()

# %% [markdown]
# It should be noted that the functions do not have an access to the variables which are defined in
# some other functions. The variables are having limited scope to their functions only

# %%
# Global variable
total = 1000

# Creating the first function
def offer():
    discount = 300  # Local variable

    # Inner function to calculate amount
def amount():
    print("The total is:", total)  # Accessing global variable
    print("The amount is:", total - discount)  # Accessing local variable from the outer function

amount()
offer()

# %% [markdown]
# However, this problem can be solved by changing the scope of the variable to “global” inside a
# function. This is done by adding the keyword “global” before the name of the variable as shown
# in the following example:

# %%
# Global variable
total = 1000

# Creating the first function
def offer():
    global discount
    discount = 300  # Local variable

    # Inner function to calculate amount
def amount():
    print("The total is:", total)  # Accessing global variable
    print("The amount is:", total - discount)  # Accessing local variable from the outer function

amount()
offer()

# %% [markdown]
# The following example uses different functions and demonstrates nesting of functions along with
# the usage of global variables:

# %%
# Global variables
vall = 0
val2 = 0
val3 = 0
ans = 0

# Creating function for displaying options
def show():
    print("Add: Adds three numbers")
    print("Subtract: Subtracts three numbers")
    print("Multiply: Multiplies three numbers")

# Creating function for accepting choice by user
def choice():
    return input("Choose an option (A for Add, S for Subtract, M for Multiply): ")

# Creating function for accepting input
def get_var():
    global vall, val2, val3
    vall = int(input('Value of first number: '))
    val2 = int(input("Value of second number: "))
    val3 = int(input("Value of third number: "))

# Creating addition function
def add():
    global ans
    ans = vall + val2 + val3

# Creating subtract function
def subtract():
    global ans
    ans = vall - val2 - val3

# Creating multiply function
def multiply():
    global ans
    ans = vall * val2 * val3

# Creating an output function
def output():
    print("The total is:", ans)

# Creating main function
def main():
    show()
    userchoice = choice()

    if userchoice == "A" or userchoice == "a":
        get_var()
        add()
        output()
    elif userchoice == "S" or userchoice == "s":
        get_var()
        subtract()
        output()
    elif userchoice == "M" or userchoice == "m":
        get_var()
        multiply()
        output()
    else:
        print("Invalid choice")

# Calling the main function
main()
