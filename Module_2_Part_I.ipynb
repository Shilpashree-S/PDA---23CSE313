# %% [markdown]
# <a href="https://colab.research.google.com/github/Shilpashree-S/PDA---23CSE313/blob/main/Module_2_Part_I.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Essentials of Python Programming**

# %% [markdown]
# - **Introduction to Python**

# %% [markdown]
# # Features of Python
#
# ## Key Features of Python
#
# Python is a versatile and widely-used programming language known for its simplicity and efficiency. Here are the main features that contribute to its popularity:
#
# 1. **Python syntax is easy to learn and code. It is developer-friendly and is a high-level programming language.**
# 2. **Like any other programming language, Python also allows branching and looping as well as modular programming using functions.**
#
# 3. **Python has an effective data handling mechanism and excellent storage facility for numeric and textual data**
#
# 4. **Python has a dynamic and automatic memory management.**
#
# 5. **Python has a wide collection of operators and functions for data structures, such as list, tuple, and dictionary.**
#
# 6. **Python has large and integrated collection of tools for data manipulation, analysis, and processing.**
#
# 7. **Python code is interpreted by interpreter. This means that line-by-line interppretation is done for efficient programming. There is no need to compile it as in many other programming languages.**
#
# 8. **Python is a platform-independent programming language and hence runs on different platforms, such as Windows, Linux, Unix, Macintosh, etc.**
#
# 9. **Python is dynamically typed. This means that the type for a value is decided at runtime, not in advance. Hence, unlike any other programming language, we do not need to specify the type of variable while declaring it.**
#
# 10. **Python has an integrated suite of software facilities for graphical interpretation.**
#
# 11. **The rich library of Python is immensely helpful in advanced algorithms related to different specializations.**
#
# 12. **The machine learning algorithms of Python have brought a revolution in the field of Data Analytics.**
#
# These features make Python a powerful tool for various applications ranging from web development to data science and automation.
#
# ### Variables in Python
# A Python identifier is a name that is used to identify variables, functions, or any other user-defined item.
# ## Characteristics of Python Variables
#
# - **Dynamic Typing**: Python is a dynamically typed language, meaning that you do not need to declare the type of a variable when you create it. The type is inferred from the value assigned to it, and it can change during execution. For example:
#
# ```python
# x = 10       # x is an integer
# x = "Hello"  # now x is a string
# ```
#
# - **Case Sensitivity**: Variable names in Python are case-sensitive. This means that `variable`, `Variable`, and `VARIABLE` would be considered three different variables.
#
# - **Memory Allocation**: When a variable is created, memory is allocated for it based on the data type of the value assigned. The Python interpreter manages memory allocation automatically.
#
# ## Naming Rules for Variables
#
# When naming variables in Python, follow these rules:
#
# - Variable names must start with a letter (a-z, A-Z) or an underscore (_).
# - They can contain letters, numbers (0-9), and underscores but cannot start with a number.
# - Variable names cannot include spaces or special characters (like @, #, $, etc.).
# - Reserved keywords (like `if`, `else`, `while`, etc.) cannot be used as variable names.
#
# Examples of valid variable names:
#
# ```python
# user_age = 20
# _userName = "Alice"
# score1 = 95
# ```
#
# Examples of invalid variable names:
#
# ```python
# 1st_score = 50      # cannot start with a number
# user-name = "Bob"   # cannot use hyphen
# ```
#
# ## Types of Variables
#
# Python supports various built-in data types that variables can hold:
#
# - **Numeric Types**: Integer values (e.g., `x = 10`)
# - **Text Type**: Strings (e.g., `name = "Alice"`)
# - **Sequence Types**: Ordered, mutable collections (e.g., `list = [1, 2, 3]`)
# - **Mapping Type**: Key-value pairs (e.g., `dictionary = {"key": "value"}`)
# - **Set Types**: Unordered collections of unique elements (e.g., `set_var = {1, 2, 3}`)
# - **Boolean Type**: Represents truth values (`True`, `False`)
#
# ## Variable Scope
#
# Variables in Python have different scopes depending on where they are defined:
#
# - **Global Variables**: Defined outside any function and accessible throughout the program.
#
# ```python
# global_var = "I am global"
#
# def print_global():
#     print(global_var)
#
# print_global()  # Output: I am global
# ```
#
# - **Local Variables**: Defined within a function and only accessible inside that function.
#
# ```python
# def print_local():
#     local_var = "I am local"
#     print(local_var)
#
# print_local()
# # print(local_var) would raise an error since local_var is not accessible here.
# ```
#
# - **Assigning Values to Variables**
#   -   An identifier is associated with an expression or a value.
#   - The = operator means assignment and does not represent mathematical equality.
#   - It should be noted that the numeric value is written without double quotes and a string value is enclosed in double quotes.
#
#
# ## Input and Output in Python
#
# Input and output operations are fundamental in Python programming, allowing interaction with users and displaying information.
#
# ### Input in Python
#
# The primary function for taking user input in Python is `input()`. This function reads a line from input, converts it to a string, and returns it.
#
# - **Basic Input**:
#
# ```python
# name = input("Enter your name: ")
# print("Hello, " + name)
# ```
#
#
# ```python
# num = input("Enter the number:")
# print("The number is: ", num, "and class is: ",type(num))
# ```
#
# - **Type Conversion**: By default, `input()` returns data as a string. To convert this input into other data types:
#
# ```python
# age = int(input("Enter your age: "))  # Converts input to an integer
# height = float(input("Enter your height: "))  # Converts input to a float
# ```
#   - **Python provides a distinct feature for taking input from the user using eval() function.**
#   - **This function considers the data type according to the nature of input provided.**
#  ```python
# #Program to take input from te user using eval() function.
# val1 = eval(input('Enter the value of first variable:'))
# print('val =',val,'type: ',type(val))
# val2 = eval(input('Enter the value of second variable:'))
# print('val2 = ',val2,'type: ', type(val2))
# val3 = eval(input('Enter the value of third variable:'))
# print('val3 = ',val3,'type: ',type(val3))
# ```
#  - **In python, it is possible to give multiple inputs by the user using one single input statement. This helps in assigning multiple variables in one statement.**
#  ```python
#  #Program to show use of accepting multiple inputs using eval() function.
#  a,b,c = eval(input('Enter three numbers: '))
#  print(a, ' +',b,' +',c,' = ',a+b+c)
#  ```
#
# ### Output in Python
#
# Output in Python is primarily handled through the `print()` function:
#
# - **Basic Output**:
#
# ```python
# print("Hello, World!")
# ```
#
# - **Using Parameters**:
#
# ```python
# print("Python", "is", "fun", sep=", ", end="!")
# ```
#
# - **Program to print multiple outputs in a single program.**
# ```
# print('Welcome')
# print('to')
# print('Python World')
# ```
# - **Print with "end" Argument**
#   - Sometimes it is convenient to view the output of a single line of printed text over several Python statements.
#   - Example: We may compute part of a complicated calculation, print an intermediate result, finish the calculation, and print the final answer with the output all appearing in one line of text.
#   - The end argument in print statement allows us to do so.
# ```python
# print('Welcome',end=' ')
# print('to',end=' ')
# print('Python World',end=' ')
# ```
#   - This will cause the cursor to remain on the same line for the next text. Hence, all the words are printed in the same line.
#
# - **Print with "sep" Argument**
#   - The print() function uses a keyword named "sep" to specify the string to use insert between items.
#   - The value of "sep" argument allows us to control how the print() function visually separates the argument it displays.
#   - The name "sep" stands for separator.
#   - By default, the print() function places a single space in between the items it prints.
#   - The default value of "sep" is a blank string ' ', which is a string containing single space.
# ```python
# #Program to show the use of "sep" argument in print statement.
# var1, var2, var3, var4 = 100, 150, 200, 250
# #Printing variables without separator.
# print(var1, var2, var3, var4)
# #Printing variables using no space as separator.
# print(var1, var2, var3, var4, sep='')
# #Printing variables using comma as separator.
# print(var1, var2, var3, var4, sep = ',')
# #Printing variables using colon as separator.
# print(var1, var2, var3, var4, sep=':')
# #Printing variables using ----- as separator.
# print(var1, var2, var3, var4, sep='-----')
# ```
#
# - **Output Formatting**:
#
# Using f-strings (Python 3.6+):
#
# ```python
# name = "Alice"
# age = 30
# print(f"{name} is {age} years old.")
# ```
#
# Using `str.format()` method:
#
# ```python
# print("The value of x is {} and y is {}".format(5, 10))
# ```
#
# ## Operators in Python
#
# ### Arithmetic Operators
# Operator | Description | Example
# ---------|-------------|--------
# +        | Addition    | 5 + 2 = 7
# -        | Subtraction | 4 - 2 = 2
# *        | Multiplication | 2 * 3 = 6
# /        | Division    | 4 / 2 = 2.0
# //       | Floor Division | 10 // 3 = 3
# %        | Modulo    | 5 % 2 = 1
# **       | Exponentiation   | 4 ** 2 = 16
#
# ### Assignment Operators
# Operator | Description | Example
# ---------|-------------|--------
# =        | Assign value | a = 7
# +=       | Add and assign | a += 1
# -=      | Subtract and assign | a = a - 3
# *=       | Multiply and assign | a *= 4
# /=      | Divide and assign | a /= 3
# %=       | Modulus and assign | a %= 10
# **=      | Exponent and assign | a **= 2
#
#
#
#
# ### Comparison Operators
# Operator | Description | Example
# ---------|-------------|--------
# ==       | Equal to    | 3 == 5 gives False
# !=       | Not equal to | 3 != 5 gives True
# <        | Less than   | 3 < 5 gives True
# >        | Greater than   | 5 > 3 gives True
# <=       | Less than or equal to   | 3 <= 5 gives True
# >=       | Greater than or equal to   | 5 >= 5 gives True
#
#
# ### Logical Operators
# Operator | Description | Example
# ---------|-------------|--------
# and      | Logical AND | (x > y) and (y > z) is true if both conditions are true.
# or       | Logical OR  | (x > y) or (y > z) is true if at least one condition is true.
# not       | Logical NOT  | Not (x > y) is true if the condition is false.
#
# ### Identity Operators
# Operator | Description | Example
# ---------|-------------|--------
# is       | Returns True if both operands refer to the same object | (x is y)
# is not      | Returns True if both operands do not refer to the same object. | (x is not y)
#
#
# ### Membership Operators
# Operator | Description | Example
# ---------|-------------|--------
# in       | Returns True if the value is found in the sequence | "A" in "ABC" gives True
# not in      | Returns True if the value is not found in the sequence. | "D" not in "ABC" gives True
#
#
# ### Bitwise Operators
# Operator | Description | Example
# ---------|-------------|--------
# &        | Bitwise AND | (x & y)
# `\|`        | Bitwise OR | (x \| y)
# ^        | Bitwise XOR | (x ^ y)
# ~        | Bitwise NOT | (~x)
# <<       | Left Shift | (x << 1)
# >>       | Right Shift | (x >> 1)
#
# - **Operator Precedence**
#   - In an Expression with multiple operators, operator precedence determines the grouping of terms in an expression and decides how an expression will be evaluated.
#   - The following table shows operator precedence in descending order:
#
# Operator | Details
# ---------|-------------
# ()        | Parenthesis
# **        | Exponential
# /, *, //, %       | Division, Multplication, Integer Division, Modulus
# +, -        | Addition and Subtraction
# >, >=, <, <=, ==, !=      | Relational Operators
# =, +=, -=, **=, /=, //-, %=       | Assignment Operators
# not, or, and  | Logical and Boolean Operators
