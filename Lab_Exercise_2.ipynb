# %% [markdown]
# <a href="https://colab.research.google.com/github/Shilpashree-S/PDA---23CSE313/blob/main/Lab_Exercise_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. Initial Setup and Global List**
#
# First, define the main list.
# This list will be accessible by all other functions.

# %%
# 1. Create list with initial items (global scope)
# We'll use a few simple items, already capitalized.
shopping_cart = ["Apples", "Milk", "Bread"]

# %% [markdown]
# Define view_list()
#
#
# Displays the current contents of the shopping cart.

# %% [markdown]
# Define append_item()
#
# This function takes user input and uses the .append() method to add it to the list. Ensure that the function checks whether the item is not present in the list before adding it.

# %% [markdown]
# Define remove_item():
#
# This function takes user input and uses the .remove() method. We include a simple try...except block to handle cases where the item isn't in the list, preventing the program from crashing.

# %% [markdown]
# Define add_multiple_items()
#
# This function asks for comma-separated input, splits it into a list, and uses the .extend() method.

# %% [markdown]
# Define capitalize_first_letter()
#
# This function takes user input, capitalizes it using .capitalize(), and adds it to the cart. We'll use .append() here, as it's the simplest way to add the modified string.

# %% [markdown]
# Define exit_program()
#
# This function handles the termination of the program.

# %%
def exit_program():
    print("Program exiting. Thank you!")
    # We will use the return value (True) in the menu loop to break it.
    return True

# %% [markdown]
# Menu-Based Program Flow
#
# Finally, create the main menu() function to loop indefinitely until the user chooses the exit option.

# %%
def menu():
    """The main interactive menu to run the shopping cart program."""

    done = False

    while not done:
        # Display options
        print("\n=== Menu ===")
        print("a. append() a single item")
        print("b. remove() an item")
        print("c. add_multiple_items() (extend)")
        print("d. capitalize_first_letter() and add")
        print("e. view_list()")
        print("f. exit()")

        choice = input("Enter your choice (i - vi): ").lower().strip()

        # Use simple if-elif-else to call the corresponding function
        if choice == 'a':
            append_item()
        elif choice == 'b':
            remove_item()
        elif choice == 'c':
            add_multiple_items()
        elif choice == 'd':
            capitalize_first_letter_and_add()
        elif choice == 'e':
            view_list() # Simply views the list without an operation before it
        elif choice == 'f':
            done = exit_program() # Sets the loop condition to True to break
        else:
            print("❌ Invalid choice. Please enter a valid option (a-f).")

# --- START THE PROGRAM ---
# It's good practice to display the initial list when the program starts
view_list()
menu()
